# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
series=pd.read_csv('/content/drive/MyDrive/brain-stroke.csv')
series
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
series.replace({'Male':1, 'Female': 0,'Other':2},inplace=True)

# %%
series.replace({'Yes':1, 'No': 0},inplace=True)
series

# %%
series.replace({'Self-employed':0, 'Private': 1, 'Govt_job':2, 'children':3 ,'Never_worked':4},inplace=True)
series
# Out:
#          id  gender   age  hypertension  heart_disease  ever_married  \
# 0      9046       1  67.0             0              1             1
# 1     51676       0  61.0             0              0             1
# 2     31112       1  80.0             0              1             1
# 3     60182       0  49.0             0              0             1
# 4      1665       0  79.0             1              0             1
# ...     ...     ...   ...           ...            ...           ...
# 5105  18234       0  80.0             1              0             1
# 5106  44873       0  81.0             0              0             1
# 5107  19723       0  35.0             0              0             1
# 5108  37544       1  51.0             0              0             1
# 5109  44679       0  44.0             0              0             1
#
#       work_type  Residence_type  avg_glucose_level   bmi  smoking_status  \
# ...

# %%
series.replace({'Urban':0, 'Rural': 1},inplace=True)
series

# %%
series.replace({'formerly smoked':0, 'never smoked': 1, 'smokes':2,'Unknown':3},inplace=True)
series

# %%
series
# Out:
#          id  gender   age  hypertension  heart_disease  ever_married  \
# 0      9046       1  67.0             0              1             1
# 1     51676       0  61.0             0              0             1
# 2     31112       1  80.0             0              1             1
# 3     60182       0  49.0             0              0             1
# 4      1665       0  79.0             1              0             1
# ...     ...     ...   ...           ...            ...           ...
# 5105  18234       0  80.0             1              0             1
# 5106  44873       0  81.0             0              0             1
# 5107  19723       0  35.0             0              0             1
# 5108  37544       1  51.0             0              0             1
# 5109  44679       0  44.0             0              0             1
#
#      work_type  Residence_type  avg_glucose_level   bmi  smoking_status  \
# ...

# %%
series.replace({'Urban':0, 'Rural': 1},inplace=True)
series1=series;
# series1
series2=series

# %%
df2 = series.mean(axis = 0, skipna = True)
print(df2)
# Out:
# id                   36517.829354
# gender                   0.414286
# age                     43.226614
# hypertension             0.097456
# heart_disease            0.054012
# ever_married             0.656164
# work_type                1.250098
# Residence_type           0.491977
# avg_glucose_level      106.147677
# bmi                     28.893237
# smoking_status           1.585519
# stroke                   0.048728
# dtype: float64

# %%
series=series.fillna(df2.bmi)

# %%
series1=series1.fillna(0)

# %%
series2=series2.dropna()

# %%
x=series.iloc[:,:11];
y=series.iloc[:,11:];

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,shuffle=True,random_state=77);
x_train.shape,x_test.shape,y_test,y_train
# Out:
# ((3577, 11),
#  (1533, 11),
#        stroke
#  3431       0
#  616        0
#  3795       0
#  888        0
#  2548       0
#  ...      ...
#  2715       0
#  258        0
#  2181       0
#  814        0
#  322        0
#
#  [1533 rows x 1 columns],
#        stroke
#  3433       0
#  1388       0
#  4261       0
#  4075       0
#  4711       0
#  ...      ...
#  1317       0
#  2283       0
#  2004       0
#  3668       0
#  607        0
#
#  [3577 rows x 1 columns])

# %%
from sklearn.svm import SVC
clf=SVC(C=100)
clf.get_params()
# Out:
# {'C': 1.0,
#  'break_ties': False,
#  'cache_size': 200,
#  'class_weight': None,
#  'coef0': 0.0,
#  'decision_function_shape': 'ovr',
#  'degree': 3,
#  'gamma': 'scale',
#  'kernel': 'rbf',
#  'max_iter': -1,
#  'probability': False,
#  'random_state': None,
#  'shrinking': True,
#  'tol': 0.001,
#  'verbose': False}

# %%
clf.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC()

# %%
y_pred=clf.predict(x_test)
from sklearn.metrics import accuracy_score,confusion_matrix
accuracy_score(y_test, y_pred)
# Out:
# 0.9582517938682322

# %%
x1=series2.iloc[:,:11];
y1=series2.iloc[:,11:];

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x1,y1,test_size=0.3,shuffle=True,random_state=77);
x_train.shape,x_test.shape,y_test,y_train
# Out:
# ((3436, 11),
#  (1473, 11),
#        stroke
#  1215       0
#  1098       0
#  3786       0
#  1714       0
#  1350       0
#  ...      ...
#  1378       0
#  3691       0
#  95         1
#  3321       0
#  2830       0
#
#  [1473 rows x 1 columns],
#        stroke
#  2951       0
#  3697       0
#  3663       0
#  1876       0
#  2410       0
#  ...      ...
#  1390       0
#  2400       0
#  2113       0
#  3838       0
#  653        0
#
#  [3436 rows x 1 columns])

# %%
clf.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC()

# %%
y_pred=clf.predict(x_test)
from sklearn.metrics import accuracy_score,confusion_matrix
accuracy_score(y_test, y_pred)
# Out:
# 0.9592668024439919
